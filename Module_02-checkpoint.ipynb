# %% [markdown]
# # EDA of visualization and training a model by given attributes

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Load given dataset
data = p.read_csv('review final.csv')
df=data.dropna()

# %%
df
# Out:
#       Rating                                             Review category
# 0          2                       Cheap product with high cost     toys
# 1          5  Very gripping and well thought out a taut plot...    books
# 2          1                                          not cool    mobile
# 3          3  This toy is for 1+ year old babies... Overall ...     toys
# 4          1                                   I hate this book    books
# ...      ...                                                ...      ...
# 2338       5                                          I love it  fashion
# 2339       4                                               Good     toys
# 2340       5                                     I am satistied  fashion
# 2341       2                                 Not worth to price     toys
# 2342       2                                                bad   mobile
#
# [2326 rows x 3 columns]

# %%
#plotting graph for distribution
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x = "Rating", data = df)
df.loc[:, 'Rating'].value_counts()
plt.title('Distribution of Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Rating')

# %%
df['Rating'].unique()
# Out:
# array([2, 5, 1, 3, 4], dtype=int64)

# %%
df["Rating"] = df['Rating'].map({5.0:"Buyable", 4.0:"Buyable", 3.0:"Buyable", 2.0:"Not Buyable", 1.0:"Not Buyable",})

# %% [markdown]
# Training model:

# %%
#!pip install nltk

# %%
#import nltk
#nltk.download('stopwords')

# %%
df
# Out:
#            Rating                                             Review category
# 0     Not Buyable                       Cheap product with high cost     toys
# 1         Buyable  Very gripping and well thought out a taut plot...    books
# 2     Not Buyable                                          not cool    mobile
# 3         Buyable  This toy is for 1+ year old babies... Overall ...     toys
# 4     Not Buyable                                   I hate this book    books
# ...           ...                                                ...      ...
# 2338      Buyable                                          I love it  fashion
# 2339      Buyable                                               Good     toys
# 2340      Buyable                                     I am satistied  fashion
# 2341  Not Buyable                                 Not worth to price     toys
# 2342  Not Buyable                                                bad   mobile
#
# [2326 rows x 3 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
import string
# remove whitespaces
df['Review']=df['Review'].str.strip()
# lowercase the text
df['Review'] = df['Review'].str.lower()
#remove punctuation
punc = string.punctuation
table = str.maketrans('','',punc)
df['Review']=df['Review'].apply(lambda x: x.translate(table))
# tokenizing each message
df['word_tokens']=df.apply(lambda x: x['Review'].split(' '),axis=1)
# removing stopwords
df['cleaned_text'] = df.apply(lambda x: [word for word in x['word_tokens'] if word not in stopwords.words('english')],axis=1)
# stemming
ps = PorterStemmer()
df['stemmed']= df.apply(lambda x: [ps.stem(word) for word in x['cleaned_text']],axis=1)
# remove single letter words
df['final_text'] = df.apply(lambda x: ' '.join([word for word in x['stemmed'] if len(word)>1]),axis=1)

# %%
# divide the set in training and test
from sklearn.model_selection import train_test_split
X,X_test,y,y_test = train_test_split(df.loc[:,'Review':],df['Rating'],test_size=0.2)

# %%
#!pip install wordcloud

# %%
df["Rating"].unique()
# Out:
# array(['Not Buyable', 'Buyable'], dtype=object)

# %%
from wordcloud import WordCloud
# Now we look at the types of words in ham and spam. We plot wordclouds for both
Negative_text=' '.join(X.loc[y=='Buyable','Review'].values)
Negative_wordcloud = WordCloud(background_color='white',max_words=2000).generate(Negative_text)

pasitive_text=' '.join(X.loc[y=='Not Buyable','Review'].values)
pasitive_wordcloud = WordCloud(background_color='white',max_words=2000).generate(pasitive_text)
plt.figure(figsize=[20,30])
plt.subplot(1,2,1)
plt.imshow(Negative_wordcloud,interpolation='bilinear')
plt.title('Sentiment:Negative')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(pasitive_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Sentiment:Pasitive')
# Out:
# Text(0.5, 1.0, 'Sentiment:Pasitive')
